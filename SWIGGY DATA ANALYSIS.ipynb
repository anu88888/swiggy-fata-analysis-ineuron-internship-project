# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import datetime
import seaborn as sns

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# # Reading csv file

# %%
df = pd.read_csv('Swiggy Bangalore Outlet Details.csv')

# %% [markdown]
# # Exploring the dataset

# %%
df.head()
# Out:
#            Shop_Name                                            Cuisine  \
# 0       Kanti Sweets                                             Sweets
# 1      Mumbai Tiffin             North Indian, Home Food, Thalis, Combo
# 2  Sri Krishna sagar  South Indian, North Indian, Fast Food, Beverag...
# 3            Al Daaz  American, Arabian, Chinese, Desserts, Fast Foo...
# 4      Beijing Bites                                      Chinese, Thai
#
#                    Location Rating Cost_for_Two
# 0  Koramangala, Koramangala    4.3        ₹ 150
# 1             Sector 5, HSR    4.4        ₹ 400
# 2    6th Block, Koramangala    4.1        ₹ 126
# 3                  HSR, HSR    4.4        ₹ 400
# 4    5th Block, Koramangala    4.1        ₹ 450

# %%
df.tail()
# Out:
#               Shop_Name                                            Cuisine  \
# 113  Wok Paper Scissors                          Pan-Asian, Chinese, Asian
# 114  Savoury Restaurant  Arabian, Middle Eastern, North Indian, Grill, ...
# 115         Royal Treat            North Indian, Chinese, Seafood, Biryani
# 116            Thali 99                                       North Indian
# 117  Mani's Dum Biryani                                    Andhra, Biryani
#
#                                Location Rating Cost_for_Two
# 113               JNC Road, Koramangala    3.9        ₹ 219
# 114                       Madiwala, BTM    4.1        ₹ 600
# 115  5th block Koramangala, Koramangala    4.2        ₹ 193
# 116            Koramangala, Koramangala    4.3        ₹ 200
# 117              1st Block, Koramangala    4.2        ₹ 400

# %%
df.dtypes
# Out:
# Shop_Name       object
# Cuisine         object
# Location        object
# Rating          object
# Cost_for_Two    object
# dtype: object

# %% [markdown]
# # cleaning of data

# %%
df['Cost_for_Two'] = df['Cost_for_Two'].str.replace('₹', '')

# %%
df.isnull().sum()
# Out:
# Shop_Name       0
# Cuisine         0
# Location        0
# Rating          0
# Cost_for_Two    0
# dtype: int64

# %%
#df[["Cost_for_Two", "Rating"]] = df[["Cost_for_Two", "Rating"]].apply(pd.to_numeric)

# %%
np.where(df.applymap(lambda x: x == ''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
df=df.drop(df.index[[98]])

# %%
df.describe()
# Out:
#          Shop_Name       Cuisine  Location Rating Cost_for_Two
# count          117           117       117    117          117
# unique         114            79        65     12           30
# top     Easy Bites  North Indian  BTM, BTM    4.1          300
# freq             2            12        13     30           16

# %%
df[["Cost_for_Two", "Rating"]] = df[["Cost_for_Two", "Rating"]].apply(pd.to_numeric)

# %%
df.dtypes
# Out:
# Shop_Name        object
# Cuisine          object
# Location         object
# Rating          float64
# Cost_for_Two      int64
# dtype: object

# %%
df
# Out:
#               Shop_Name                                            Cuisine  \
# 0          Kanti Sweets                                             Sweets
# 1         Mumbai Tiffin             North Indian, Home Food, Thalis, Combo
# 2     Sri Krishna sagar  South Indian, North Indian, Fast Food, Beverag...
# 3               Al Daaz  American, Arabian, Chinese, Desserts, Fast Foo...
# 4         Beijing Bites                                      Chinese, Thai
# ..                  ...                                                ...
# 113  Wok Paper Scissors                          Pan-Asian, Chinese, Asian
# 114  Savoury Restaurant  Arabian, Middle Eastern, North Indian, Grill, ...
# 115         Royal Treat            North Indian, Chinese, Seafood, Biryani
# 116            Thali 99                                       North Indian
# 117  Mani's Dum Biryani                                    Andhra, Biryani
#
#                                Location  Rating  Cost_for_Two
# ...

# %%
df[['area','location_spot','hh','ff']]=df['Location'].str.split(',',expand=True)

# %%
df.head()
# Out:
#            Shop_Name                                            Cuisine  \
# 0       Kanti Sweets                                             Sweets
# 1      Mumbai Tiffin             North Indian, Home Food, Thalis, Combo
# 2  Sri Krishna sagar  South Indian, North Indian, Fast Food, Beverag...
# 3            Al Daaz  American, Arabian, Chinese, Desserts, Fast Foo...
# 4      Beijing Bites                                      Chinese, Thai
#
#                    Location  Rating  Cost_for_Two         area location_spot  \
# 0  Koramangala, Koramangala     4.3           150  Koramangala   Koramangala
# 1             Sector 5, HSR     4.4           400     Sector 5           HSR
# 2    6th Block, Koramangala     4.1           126    6th Block   Koramangala
# 3                  HSR, HSR     4.4           400          HSR           HSR
# 4    5th Block, Koramangala     4.1           450    5th Block   Koramangala
#
#      hh    ff
# 0  None  None
# 1  None  None
# 2  None  None
# ...

# %%
df=df.drop('hh',axis=1)

# %%
df=df.drop('ff',axis=1)

# %%
df=df.drop('Location',axis=1)

# %%
df
# Out:
#               Shop_Name                                            Cuisine  \
# 0          Kanti Sweets                                             Sweets
# 1         Mumbai Tiffin             North Indian, Home Food, Thalis, Combo
# 2     Sri Krishna sagar  South Indian, North Indian, Fast Food, Beverag...
# 3               Al Daaz  American, Arabian, Chinese, Desserts, Fast Foo...
# 4         Beijing Bites                                      Chinese, Thai
# ..                  ...                                                ...
# 113  Wok Paper Scissors                          Pan-Asian, Chinese, Asian
# 114  Savoury Restaurant  Arabian, Middle Eastern, North Indian, Grill, ...
# 115         Royal Treat            North Indian, Chinese, Seafood, Biryani
# 116            Thali 99                                       North Indian
# 117  Mani's Dum Biryani                                    Andhra, Biryani
#
#      Rating  Cost_for_Two                   area location_spot
# ...

# %%
df['cost_of_one'] = df['Cost_for_Two']/2

# %%
df
# Out:
#               Shop_Name                                            Cuisine  \
# 0          Kanti Sweets                                             Sweets
# 1         Mumbai Tiffin             North Indian, Home Food, Thalis, Combo
# 2     Sri Krishna sagar  South Indian, North Indian, Fast Food, Beverag...
# 3               Al Daaz  American, Arabian, Chinese, Desserts, Fast Foo...
# 4         Beijing Bites                                      Chinese, Thai
# ..                  ...                                                ...
# 113  Wok Paper Scissors                          Pan-Asian, Chinese, Asian
# 114  Savoury Restaurant  Arabian, Middle Eastern, North Indian, Grill, ...
# 115         Royal Treat            North Indian, Chinese, Seafood, Biryani
# 116            Thali 99                                       North Indian
# 117  Mani's Dum Biryani                                    Andhra, Biryani
#
# ...

# %%
location=df['location_spot'].value_counts().sort_values(ascending
=False)

# %%
location
# Out:
#  Koramangala         63
#  BTM                 33
#  HSR                 15
#  Stage 2              1
#  Jayanagar            1
#  5th Block            1
#  Sector 6             1
#  2nd Stage            1
#  Teacher's Colony     1
# Name: location_spot, dtype: int64

# %%
#koromangala has the highest numbers of shops followed by BTM and HSR.

# %%
df.to_csv(r'C:\Users\Anurag\Desktop\New folder(2).csv', index=False)

# %%
#charts and visualization is done on power bi form the cleaned data made from above saved pyhton file.
